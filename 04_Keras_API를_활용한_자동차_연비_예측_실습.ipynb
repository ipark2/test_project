# %% [markdown]
# <a href="https://colab.research.google.com/github/ipark2/test_project/blob/main/04_Keras_API%EB%A5%BC_%ED%99%9C%EC%9A%A9%ED%95%9C_%EC%9E%90%EB%8F%99%EC%B0%A8_%EC%97%B0%EB%B9%84_%EC%98%88%EC%B8%A1_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DNN(MLP) 모델을 이용한 자동차 연비 데이터 셋 회귀 분석

# %%
import matplotlib.pyplot as plt
import pandas as pd

import tensorflow as tf
from tensorflow.keras import layers, models

# %%
print(tf.__version__)
# Out:
# 2.8.2

# %% [markdown]
# ### Step 1-1. Inptu tensor 와 Target tensor 준비(훈련데이터)
# * 자동차 연비 데이터셋 파일 down

# %%
auto_mpg_dataset_url = "http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
dataset_path = tf.keras.utils.get_file("/content/auto-mpg.data", auto_mpg_dataset_url)
dataset_path
# Out:
# Downloading data from http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data
# 32768/30286 [================================] - 0s 1us/step
# 40960/30286 [========================================] - 0s 1us/step
# '/content/auto-mpg.data'

# %% [markdown]
# *  데이터 셋 파일을 읽어 Dataframe 객체 생성

# %%
# 자동차 연비 데이터 셋의 컬럼명
column_names = ['MPG','Cylinders','Displacement','Horsepower','Weight',
                'Acceleration', 'Model Year', 'Origin']

raw_dataset = pd.read_csv(dataset_path, names=column_names,
                          na_values='?', comment='\t',
                          sep=" ", skipinitialspace=True)

dataset = raw_dataset.copy()
dataset
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# 4            70       1
# ..          ...     ...
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1
#
# [398 rows x 8 columns]

# %% [markdown]
# ### Step 1-2. 입력 데이터의 전처리
# * 데이터 셋 내의 NaN 값 제거

# %%
# 데이터 셋 내의 Nan 값 체크
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %%
# 데이터 셋 내 의 Nan 값 제거
dataset = dataset.dropna()

# %%
len(dataset)
# Out:
# 392

# %%
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      0
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %% [markdown]
# * 데이터셋 에서 20% 선택하여 test 데이터 셋으로 분할

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %%
print(len(train_dataset))
print(len(test_dataset))
# Out:
# 314
# 78

# %% [markdown]
# * 표준화를 통한 Input tensor의 전처리

# %%
# 데이터 전처리를 위한 통계정보 생성
train_stats = train_dataset.describe()

# %%
train_stats
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  314.000000  314.000000    314.000000  314.000000   314.000000
# mean    23.310510    5.477707    195.318471  104.869427  2990.251592
# std      7.728652    1.699788    104.331589   38.096214   843.898596
# min     10.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     17.000000    4.000000    105.500000   76.250000  2256.500000
# 50%     22.000000    4.000000    151.000000   94.500000  2822.500000
# 75%     28.950000    8.000000    265.750000  128.000000  3608.000000
# max     46.600000    8.000000    455.000000  225.000000  5140.000000
#
#        Acceleration  Model Year      Origin
# count    314.000000  314.000000  314.000000
# mean      15.559236   75.898089    1.573248
# std        2.789230    3.675642    0.800988
# min        8.000000   70.000000    1.000000
# 25%       13.800000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.200000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %%
# 정답 데이터(MPG-연비) 제거
train_stats.pop('MPG')
# Out:
# count    314.000000
# mean      23.310510
# std        7.728652
# min       10.000000
# 25%       17.000000
# 50%       22.000000
# 75%       28.950000
# max       46.600000
# Name: MPG, dtype: float64

# %%
train_stats
# Out:
#         Cylinders  Displacement  Horsepower       Weight  Acceleration  \
# count  314.000000    314.000000  314.000000   314.000000    314.000000
# mean     5.477707    195.318471  104.869427  2990.251592     15.559236
# std      1.699788    104.331589   38.096214   843.898596      2.789230
# min      3.000000     68.000000   46.000000  1649.000000      8.000000
# 25%      4.000000    105.500000   76.250000  2256.500000     13.800000
# 50%      4.000000    151.000000   94.500000  2822.500000     15.500000
# 75%      8.000000    265.750000  128.000000  3608.000000     17.200000
# max      8.000000    455.000000  225.000000  5140.000000     24.800000
#
#        Model Year      Origin
# count  314.000000  314.000000
# mean    75.898089    1.573248
# std      3.675642    0.800988
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
# 각 특성 별 통계정보를 가공하기 쉽도록 matrix 전치
train_stats = train_stats.transpose()

# %%
train_stats
# Out:
#               count         mean         std     min      25%     50%  \
# Cylinders     314.0     5.477707    1.699788     3.0     4.00     4.0
# Displacement  314.0   195.318471  104.331589    68.0   105.50   151.0
# Horsepower    314.0   104.869427   38.096214    46.0    76.25    94.5
# Weight        314.0  2990.251592  843.898596  1649.0  2256.50  2822.5
# Acceleration  314.0    15.559236    2.789230     8.0    13.80    15.5
# Model Year    314.0    75.898089    3.675642    70.0    73.00    76.0
# Origin        314.0     1.573248    0.800988     1.0     1.00     1.0
#
#                   75%     max
# Cylinders        8.00     8.0
# Displacement   265.75   455.0
# Horsepower     128.00   225.0
# Weight        3608.00  5140.0
# Acceleration    17.20    24.8
# Model Year      79.00    82.0
# Origin           2.00     3.0

# %%
# Target tensor 를 위한 연비 값(MPG - Miles Per Gallon) 추출
train_labels = train_dataset.pop('MPG')
test_labels = test_dataset.pop('MPG')

# %%
train_dataset
# Out:
#      Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year  \
# 146          4          90.0        75.0  2125.0          14.5          74
# 282          4         140.0        88.0  2890.0          17.3          79
# 69           8         350.0       160.0  4456.0          13.5          72
# 378          4         105.0        63.0  2125.0          14.7          82
# 331          4          97.0        67.0  2145.0          18.0          80
# ..         ...           ...         ...     ...           ...         ...
# 281          6         200.0        85.0  2990.0          18.2          79
# 229          8         400.0       180.0  4220.0          11.1          77
# 150          4         108.0        93.0  2391.0          15.5          74
# 145          4          83.0        61.0  2003.0          19.0          74
# 182          4         107.0        86.0  2464.0          15.5          76
#
#      Origin
# 146       1
# 282       1
# 69        1
# 378       1
# 331       3
# ..      ...
# 281       1
# 229       1
# 150       3
# 145       3
# 182       2
#
# [314 rows x 7 columns]

# %%
# Input tensor의 표준화(평균 :0/ 표준편차 :1) 함수 정의
def norm(x):
  normed_data = (x - train_stats['mean']) / train_stats['std']
  return normed_data

# %%
# Input tensor 의 특성 정보 표준화 처리 수행
train_dataset = norm(train_dataset)
test_dataset = norm(test_dataset)

# %%
train_dataset.describe()
# Out:
#           Cylinders  Displacement    Horsepower        Weight  Acceleration  \
# count  3.140000e+02  3.140000e+02  3.140000e+02  3.140000e+02  3.140000e+02
# mean   1.824443e-16  8.627211e-17 -9.900078e-18 -8.485781e-17 -5.148041e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.457657e+00 -1.220325e+00 -1.545283e+00 -1.589352e+00 -2.710152e+00
# 25%   -8.693480e-01 -8.608943e-01 -7.512407e-01 -8.694784e-01 -6.307245e-01
# 50%   -8.693480e-01 -4.247848e-01 -2.721905e-01 -1.987817e-01 -2.123729e-02
# 75%    1.483887e+00  6.750739e-01  6.071620e-01  7.320173e-01  5.882500e-01
# max    1.483887e+00  2.489002e+00  3.153347e+00  2.547401e+00  3.313017e+00
#
#          Model Year        Origin
# count  3.140000e+02  3.140000e+02
# mean   9.772791e-16 -9.617219e-17
# std    1.000000e+00  1.000000e+00
# min   -1.604642e+00 -7.156763e-01
# 25%   -7.884578e-01 -7.156763e-01
# 50%    2.772599e-02 -7.156763e-01
# 75%    8.439098e-01  5.327813e-01
# max    1.660094e+00  1.781239e+00

# %% [markdown]
# ### Step2. DNN(MLP) 모델 디자인

# %%
# hidden layer : 2개[64, 32], activation : relu
model = models.Sequential()
model.add(layers.Dense(units=64, activation='relu', input_shape=(len(train_dataset.keys()),)))
model.add(layers.Dense(units=32, activation='relu'))
model.add(layers.Dense(units=1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                512
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Step 3. 모델의 학습 정보 설정

# %%
# loss : mean square error/ optimizer : rmsprop/ metric : mean absolute error
model.compile(loss='mse',
              optimizer='rmsprop',
              metrics=['mae'])

# %% [markdown]
# ### Step 4. 모델에 input, target 데이터 연결 후 학습

# %%
# batch size : 16, epochs : 100, validation data set percent : 20%
history = model.fit(
    x=train_dataset, y=train_labels,
    batch_size=16,
    epochs=100,
    validation_split=0.2
)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 1s 15ms/step - loss: 578.2551 - mae: 22.8043 - val_loss: 575.2188 - val_mae: 22.7165
# Epoch 2/100
# 16/16 [==============================] - 0s 3ms/step - loss: 531.5392 - mae: 21.7879 - val_loss: 521.9125 - val_mae: 21.5370
# Epoch 3/100
# 16/16 [==============================] - 0s 3ms/step - loss: 475.1294 - mae: 20.5007 - val_loss: 453.4782 - val_mae: 19.9407
# Epoch 4/100
# 16/16 [==============================] - 0s 4ms/step - loss: 405.5669 - mae: 18.8088 - val_loss: 371.6095 - val_mae: 17.8922
# Epoch 5/100
# 16/16 [==============================] - 0s 4ms/step - loss: 324.1752 - mae: 16.6639 - val_loss: 280.6283 - val_mae: 15.3213
# Epoch 6/100
# 16/16 [==============================] - 0s 4ms/step - loss: 238.8563 - mae: 14.1119 - val_loss: 192.3486 - val_mae: 12.4566
# Epoch 7/100
# 16/16 [==============================] - 0s 4ms/step - loss: 157.1535 - mae: 11.2873 - val_loss: 114.2393 - val_mae: 9.4749
# Epoch 8/100
# 16/16 [==============================] - 0s 5ms/step - loss: 91.5919 - mae: 8.3733 - val_loss: 61.4544 - val_mae: 6.8107
# Epoch 9/100
# 16/16 [==============================] - 0s 4ms/step - loss: 52.0527 - mae: 5.8559 - val_loss: 40.5650 - val_mae: 5.4885
# Epoch 10/100
# 16/16 [==============================] - 0s 4ms/step - loss: 36.6664 - mae: 4.7654 - val_loss: 34.9762 - val_mae: 4.8940
# Epoch 11/100
# 16/16 [==============================] - 0s 3ms/step - loss: 30.6269 - mae: 4.3495 - val_loss: 30.7060 - val_mae: 4.5679
# Epoch 12/100
# 16/16 [==============================] - 0s 4ms/step - loss: 26.4783 - mae: 4.0450 - val_loss: 26.9194 - val_mae: 4.2216
# Epoch 13/100
# 16/16 [==============================] - 0s 5ms/step - loss: 22.8597 - mae: 3.7426 - val_loss: 23.9760 - val_mae: 3.9237
# Epoch 14/100
# 16/16 [==============================] - 0s 4ms/step - loss: 20.0980 - mae: 3.4907 - val_loss: 22.2616 - val_mae: 3.7615
# Epoch 15/100
# 16/16 [==============================] - 0s 4ms/step - loss: 18.0995 - mae: 3.3187 - val_loss: 19.3055 - val_mae: 3.5035
# Epoch 16/100
# 16/16 [==============================] - 0s 5ms/step - loss: 16.2717 - mae: 3.0956 - val_loss: 18.2016 - val_mae: 3.3246
# Epoch 17/100
# 16/16 [==============================] - 0s 3ms/step - loss: 14.8988 - mae: 2.9726 - val_loss: 15.8669 - val_mae: 3.1608
# Epoch 18/100
# 16/16 [==============================] - 0s 4ms/step - loss: 13.5157 - mae: 2.7835 - val_loss: 14.5597 - val_mae: 3.0049
# Epoch 19/100
# 16/16 [==============================] - 0s 3ms/step - loss: 12.6269 - mae: 2.6823 - val_loss: 13.6029 - val_mae: 2.9562
# Epoch 20/100
# 16/16 [==============================] - 0s 4ms/step - loss: 11.7104 - mae: 2.5598 - val_loss: 13.0321 - val_mae: 2.8943
# Epoch 21/100
# 16/16 [==============================] - 0s 4ms/step - loss: 11.2263 - mae: 2.4678 - val_loss: 12.3454 - val_mae: 2.7544
# Epoch 22/100
# 16/16 [==============================] - 0s 4ms/step - loss: 10.3754 - mae: 2.3499 - val_loss: 12.1987 - val_mae: 2.6386
# Epoch 23/100
# 16/16 [==============================] - 0s 3ms/step - loss: 10.3563 - mae: 2.3233 - val_loss: 11.9719 - val_mae: 2.6132
# Epoch 24/100
# 16/16 [==============================] - 0s 4ms/step - loss: 9.9431 - mae: 2.2588 - val_loss: 11.5182 - val_mae: 2.6173
# Epoch 25/100
# 16/16 [==============================] - 0s 3ms/step - loss: 9.6496 - mae: 2.2685 - val_loss: 11.1099 - val_mae: 2.5486
# Epoch 26/100
# 16/16 [==============================] - 0s 3ms/step - loss: 9.2102 - mae: 2.1729 - val_loss: 11.4100 - val_mae: 2.5108
# Epoch 27/100
# 16/16 [==============================] - 0s 3ms/step - loss: 9.2663 - mae: 2.1875 - val_loss: 10.9157 - val_mae: 2.5802
# Epoch 28/100
# 16/16 [==============================] - 0s 5ms/step - loss: 8.9971 - mae: 2.1318 - val_loss: 10.8384 - val_mae: 2.5382
# Epoch 29/100
# 16/16 [==============================] - 0s 3ms/step - loss: 8.8265 - mae: 2.1067 - val_loss: 10.4544 - val_mae: 2.4707
# Epoch 30/100
# 16/16 [==============================] - 0s 4ms/step - loss: 8.4549 - mae: 2.0816 - val_loss: 11.2605 - val_mae: 2.6472
# Epoch 31/100
# 16/16 [==============================] - 0s 4ms/step - loss: 8.2448 - mae: 2.0392 - val_loss: 10.6419 - val_mae: 2.4104
# Epoch 32/100
# 16/16 [==============================] - 0s 5ms/step - loss: 8.2771 - mae: 2.0471 - val_loss: 10.2257 - val_mae: 2.4753
# Epoch 33/100
# 16/16 [==============================] - 0s 5ms/step - loss: 8.1662 - mae: 2.0410 - val_loss: 10.3095 - val_mae: 2.4609
# Epoch 34/100
# 16/16 [==============================] - 0s 4ms/step - loss: 8.0831 - mae: 2.0036 - val_loss: 10.1778 - val_mae: 2.4120
# Epoch 35/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.8234 - mae: 2.0145 - val_loss: 10.0514 - val_mae: 2.4435
# Epoch 36/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.7799 - mae: 1.9834 - val_loss: 9.5926 - val_mae: 2.3585
# Epoch 37/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.8665 - mae: 1.9846 - val_loss: 9.7052 - val_mae: 2.3748
# Epoch 38/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.6558 - mae: 1.9741 - val_loss: 9.6748 - val_mae: 2.3770
# Epoch 39/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.4828 - mae: 1.9315 - val_loss: 10.0023 - val_mae: 2.4571
# Epoch 40/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.6013 - mae: 1.9409 - val_loss: 10.3852 - val_mae: 2.5346
# Epoch 41/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.4967 - mae: 1.9480 - val_loss: 9.4729 - val_mae: 2.3716
# Epoch 42/100
# 16/16 [==============================] - 0s 3ms/step - loss: 7.4176 - mae: 1.9354 - val_loss: 9.5218 - val_mae: 2.3709
# Epoch 43/100
# 16/16 [==============================] - 0s 3ms/step - loss: 7.2756 - mae: 1.8973 - val_loss: 10.4985 - val_mae: 2.5618
# Epoch 44/100
# 16/16 [==============================] - 0s 3ms/step - loss: 7.3752 - mae: 1.9180 - val_loss: 9.5965 - val_mae: 2.4128
# Epoch 45/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.2754 - mae: 1.8914 - val_loss: 9.3867 - val_mae: 2.3424
# Epoch 46/100
# 16/16 [==============================] - 0s 3ms/step - loss: 7.1163 - mae: 1.8795 - val_loss: 9.9192 - val_mae: 2.4646
# Epoch 47/100
# 16/16 [==============================] - 0s 3ms/step - loss: 7.1022 - mae: 1.8770 - val_loss: 9.4800 - val_mae: 2.2996
# Epoch 48/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.2759 - mae: 1.9047 - val_loss: 9.1892 - val_mae: 2.2900
# Epoch 49/100
# 16/16 [==============================] - 0s 3ms/step - loss: 7.0631 - mae: 1.8885 - val_loss: 9.1901 - val_mae: 2.3106
# Epoch 50/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.0558 - mae: 1.8617 - val_loss: 9.4122 - val_mae: 2.2995
# Epoch 51/100
# 16/16 [==============================] - 0s 3ms/step - loss: 6.9166 - mae: 1.8129 - val_loss: 9.5612 - val_mae: 2.4100
# Epoch 52/100
# 16/16 [==============================] - 0s 3ms/step - loss: 6.9927 - mae: 1.8483 - val_loss: 9.9154 - val_mae: 2.4601
# Epoch 53/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.9235 - mae: 1.8279 - val_loss: 9.4346 - val_mae: 2.3879
# Epoch 54/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.8580 - mae: 1.8375 - val_loss: 9.3797 - val_mae: 2.2981
# Epoch 55/100
# 16/16 [==============================] - 0s 3ms/step - loss: 6.9264 - mae: 1.8365 - val_loss: 9.2519 - val_mae: 2.3350
# Epoch 56/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.7679 - mae: 1.8049 - val_loss: 9.3763 - val_mae: 2.3346
# Epoch 57/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.8692 - mae: 1.8351 - val_loss: 9.1245 - val_mae: 2.2699
# Epoch 58/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.7235 - mae: 1.8138 - val_loss: 9.0547 - val_mae: 2.3097
# Epoch 59/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6075 - mae: 1.8051 - val_loss: 9.4945 - val_mae: 2.3827
# Epoch 60/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5898 - mae: 1.8207 - val_loss: 9.4312 - val_mae: 2.3852
# Epoch 61/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6568 - mae: 1.7875 - val_loss: 9.4064 - val_mae: 2.3747
# Epoch 62/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.5732 - mae: 1.7837 - val_loss: 9.1186 - val_mae: 2.2811
# Epoch 63/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5479 - mae: 1.7958 - val_loss: 9.0577 - val_mae: 2.2574
# Epoch 64/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6720 - mae: 1.8077 - val_loss: 9.0606 - val_mae: 2.3324
# Epoch 65/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6056 - mae: 1.7927 - val_loss: 9.1606 - val_mae: 2.2672
# Epoch 66/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.5985 - mae: 1.7700 - val_loss: 9.0103 - val_mae: 2.2692
# Epoch 67/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.5335 - mae: 1.7662 - val_loss: 9.0514 - val_mae: 2.2775
# Epoch 68/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.4950 - mae: 1.7740 - val_loss: 9.3278 - val_mae: 2.2790
# Epoch 69/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5132 - mae: 1.8139 - val_loss: 9.2884 - val_mae: 2.3643
# Epoch 70/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6553 - mae: 1.7936 - val_loss: 9.0561 - val_mae: 2.2765
# Epoch 71/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3443 - mae: 1.7194 - val_loss: 8.9662 - val_mae: 2.2652
# Epoch 72/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.4405 - mae: 1.7636 - val_loss: 9.4831 - val_mae: 2.4101
# Epoch 73/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.4936 - mae: 1.7323 - val_loss: 9.0731 - val_mae: 2.2889
# Epoch 74/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3759 - mae: 1.7470 - val_loss: 9.1646 - val_mae: 2.2850
# Epoch 75/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.2733 - mae: 1.7530 - val_loss: 9.4699 - val_mae: 2.2494
# Epoch 76/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.1655 - mae: 1.7052 - val_loss: 10.3625 - val_mae: 2.3154
# Epoch 77/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.4047 - mae: 1.7737 - val_loss: 8.9488 - val_mae: 2.3117
# Epoch 78/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.2809 - mae: 1.7542 - val_loss: 9.7209 - val_mae: 2.4246
# Epoch 79/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3850 - mae: 1.7548 - val_loss: 9.1647 - val_mae: 2.3623
# Epoch 80/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.3260 - mae: 1.7323 - val_loss: 9.4359 - val_mae: 2.2413
# Epoch 81/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.4005 - mae: 1.7506 - val_loss: 9.1751 - val_mae: 2.3299
# Epoch 82/100
# 16/16 [==============================] - 0s 3ms/step - loss: 6.2429 - mae: 1.7179 - val_loss: 9.2431 - val_mae: 2.3659
# Epoch 83/100
# 16/16 [==============================] - 0s 3ms/step - loss: 6.1694 - mae: 1.7263 - val_loss: 9.2016 - val_mae: 2.3636
# Epoch 84/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.2704 - mae: 1.7150 - val_loss: 9.0488 - val_mae: 2.3238
# Epoch 85/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.2861 - mae: 1.7236 - val_loss: 9.0633 - val_mae: 2.3090
# Epoch 86/100
# 16/16 [==============================] - 0s 3ms/step - loss: 6.1245 - mae: 1.7135 - val_loss: 9.1165 - val_mae: 2.3059
# Epoch 87/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.1926 - mae: 1.7227 - val_loss: 9.0621 - val_mae: 2.2699
# Epoch 88/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.1371 - mae: 1.6914 - val_loss: 9.2290 - val_mae: 2.3716
# Epoch 89/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.1780 - mae: 1.7230 - val_loss: 8.9511 - val_mae: 2.2987
# Epoch 90/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.0970 - mae: 1.6958 - val_loss: 9.1185 - val_mae: 2.2520
# Epoch 91/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.1322 - mae: 1.7119 - val_loss: 9.1208 - val_mae: 2.3552
# Epoch 92/100
# 16/16 [==============================] - 0s 4ms/step - loss: 5.7989 - mae: 1.6750 - val_loss: 8.9583 - val_mae: 2.2679
# Epoch 93/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.1158 - mae: 1.6894 - val_loss: 9.0418 - val_mae: 2.2112
# Epoch 94/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.0985 - mae: 1.6978 - val_loss: 9.0645 - val_mae: 2.3028
# Epoch 95/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.0159 - mae: 1.6867 - val_loss: 9.1831 - val_mae: 2.3186
# Epoch 96/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.1252 - mae: 1.6777 - val_loss: 9.3497 - val_mae: 2.3257
# Epoch 97/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.0216 - mae: 1.7012 - val_loss: 9.2727 - val_mae: 2.2537
# Epoch 98/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.0631 - mae: 1.6869 - val_loss: 9.4160 - val_mae: 2.3970
# Epoch 99/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.1146 - mae: 1.6989 - val_loss: 9.2789 - val_mae: 2.3554
# Epoch 100/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.9496 - mae: 1.6815 - val_loss: 9.3877 - val_mae: 2.3800

# %% [markdown]
# ### 학습과정의 시각화 및 성능 테스트

# %%
hist = pd.DataFrame(history.history)
hist
# Out:
#           loss        mae    val_loss    val_mae
# 0   578.255066  22.804348  575.218750  22.716476
# 1   531.539185  21.787945  521.912476  21.537012
# 2   475.129364  20.500700  453.478180  19.940701
# 3   405.566864  18.808788  371.609497  17.892195
# 4   324.175201  16.663935  280.628326  15.321284
# ..         ...        ...         ...        ...
# 95    6.125231   1.677733    9.349736   2.325725
# 96    6.021572   1.701215    9.272722   2.253654
# 97    6.063055   1.686943    9.416028   2.397039
# 98    6.114575   1.698881    9.278852   2.355440
# 99    5.949586   1.681464    9.387707   2.379972
#
# [100 rows x 4 columns]

# %%
# 학습과정 시각화를 위한 정보 추출
loss = history.history['loss']
val_loss = history.history['val_loss']

mae = history.history['mae']
val_mae = history.history['val_mae']

# %%
# 차트의 x 축을 위한 epoch 정보 생성
epochs = range(1, len(loss)+1)

# %%
# loss 정보 시각화
plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('Training and validation loss')
plt.ylim([0,20])
plt.legend()

plt.show()

# %%
# Mean Absolute Error 정보 시각화
plt.plot(epochs, mae, label='Training mae')
plt.plot(epochs, val_mae, label='Validation mae')
plt.title('Training and validation mae')
plt.xlim([1,100])
plt.ylim([0,5])
plt.legend()

plt.show()

# %%
# 테스트 데이터 셋을 통한 성능 측정
test_loss, test_mae = model.evaluate(x=test_dataset, y=test_labels)
# Out:
# 3/3 [==============================] - 0s 2ms/step - loss: 6.9180 - mae: 1.9322

# %%
# 테스트 데이터 셋의 정답과 모델의 예측값 분석을 위한 모델의 예측값 생성
test_predictions = model.predict(test_dataset).flatten()

# %%
# 테스트 데이터 셋의 정답과 모델의 예측값을 이용한 상관 관계 시각화
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0, 50])
plt.ylim([0,50])
_ = plt.plot([-100, 100], [-100, 100])
